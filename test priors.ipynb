# %%
import jax
import jax.numpy as jnp
import jax.random as jr
import matplotlib.pyplot as plt
import priors

# %%
rngs = jr.split(jr.key(0), 10000)

# Normal distribution
distr = priors.PeriodicUniform(2.0)
xs = jax.vmap(distr.sample)(rngs)
print(xs.shape)
plt.hist(xs.flatten(), bins=100, density=True);
ys = distr.step(xs, 1, 0.1)
plt.hist(ys.flatten(), bins=100, density=True);
# Out:
# (10000, 1)
